# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
afr = pd.read_csv("C:/Users/PROSPERITY/Documents/HamoyeDSI/FoodBalanceSheets_E_Africa_NOFLAG.csv", 
                  encoding='latin-1')
afr.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
x = afr.groupby("Area")["Y2017"].sum()
grouped = x.sort_values()
grouped
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
total_null = afr["Y2014"].isnull().sum()
percent_null = (afr["Y2014"].isnull().sum())*100/len(afr["Y2014"])
print("The total number of null values is ", total_null,
      "and the percentage of null values is ",percent_null)
# Out:
# The total number of null values is  1589 and the percentage of null values is  2.6073544131401474

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ["Age","Nationality","Overall"]
df = pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
df.head()
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
df2 = pd.DataFrame(lst, columns = col, index = [1,2,3])
df2.head()
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
afr["Area"].nunique()
# Out:
# 49

# %%
afr.groupby(["Item"]).sum()
# Out:
#                      Area Code  \
# Item
# Alcohol, Non-Food        38447
# Alcoholic Beverages      75016
# Animal Products          18060
# Animal fats              85279
# Apples and products      69280
# ...                        ...
# Vegetables, Other        77779
# Vegetal Products         18060
# Wheat and products       87073
# Wine                     66206
# Yams                     50798
#
#                                                                   Area  \
# Item
# Alcohol, Non-Food    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAngo...
# Alcoholic Beverages  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Animal Products      AlgeriaAlgeriaAlgeriaAngolaAngolaAngolaBeninBe...
# Animal fats          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Apples and products  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...                                                                ...
# ...

# %%
afr.groupby(["Element"]).sum()
# Out:
#                                         Area Code  \
# Element
# Domestic supply quantity                   708993
# Export Quantity                            599910
# Fat supply quantity (g/capita/day)         675050
# Feed                                       176272
# Food                                       663295
# Food supply (kcal/capita/day)              674057
# Food supply quantity (kg/capita/yr)        658446
# Import Quantity                            688174
# Losses                                     274353
# Other uses (non-food)                      235554
# Processing                                 271940
# Production                                 526751
# Protein supply quantity (g/capita/day)     675050
# Residuals                                  623271
# Seed                                       103537
# Stock Variation                            571566
# Total Population - Both sexes                6020
# ...

# %%
afr.iloc[1:2,10:12]
# Out:
#    Y2017  Y2018
# 1    0.0    0.0

# %%
afr.groupby("Area")["Y2017"].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
afr.groupby(['Area','Element']).sum()
# Out:
#                                                  Area Code  Item Code  \
# Area     Element
# Algeria  Domestic supply quantity                      464     311204
#          Export Quantity                               392     264011
#          Fat supply quantity (g/capita/day)            432     291489
#          Feed                                           88      58967
#          Food                                          420     282744
# ...                                                    ...        ...
# Zimbabwe Protein supply quantity (g/capita/day)      20453     304589
#          Residuals                                   18824     277476
#          Seed                                         3439      50560
#          Stock Variation                             17195     254157
#          Total Population - Both sexes                 181       2501
#
#                                                                                               Item  \
# ...

# %%
afr["Y2017"].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
numerical = ["Y2014", "Y2015", "Y2016", "Y2017"]
for i in numerical:
    print("Correlation for ", i, ":",afr["Element Code"].corr(afr[i]))
# Out:
# Correlation for  Y2014 : 0.024456819495221795
# Correlation for  Y2015 : 0.02388919930163992
# Correlation for  Y2016 : 0.023443997584961428
# Correlation for  Y2017 : 0.02425400776004572

# %%
array1  = np.array([[94, 89, 63],[93, 92, 48],[92, 94, 56]])
arr1 = array1[:2,1:]
arr1
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
afr.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
y[1][1]
# Out:
# 8

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment
